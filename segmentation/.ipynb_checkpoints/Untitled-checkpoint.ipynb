# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
# %matplotlib inline

# Read in the image
image = cv2.imread('a2.jpg')

# Change color to RGB (from BGR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)

# %%
image_copy = np.copy(image)
#hsv= cv2.cvtColor(image_copy, cv2.COLOR_BGR2HSV)
plt.imshow(image_copy)

#inRange(hsv, Scalar(0, 70, 50), Scalar(10, 255, 255), mask1);
   # inRange(hsv, Scalar(170, 70, 50), Scalar(180, 255, 255), mask2);

# %%
from PIL import Image
upper_blue = np.array([255, 0, 0]) 
lower_blue = np.array([139, 0, 0])
mask_hsv = cv2.inRange(image_copy , lower_blue , upper_blue )


#image_copy[mask_hsv == 0] = [0,0,0]
img = Image.fromarray(lower_blue, 'RGB')
plt.imshow(mask_hsv)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-cf13ccdd0bbc> in <module>
#       6
#       7 #image_copy[mask_hsv == 0] = [0,0,0]
# ----> 8 img = Image.fromarray(lower_blue, 'RGB')
#       9 plt.imshow(mask_hsv)
#
# ~/anaconda3/envs/segmentation/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2527         raise ValueError("Too many dimensions: %d > %d." % (ndim, ndmax))
#    2528
# -> 2529     size = shape[1], shape[0]
#    2530     if strides is not None:
#    2531         if hasattr(obj, 'tobytes'):
#
# IndexError: tuple index out of range

# %%
plt.imshow(prova)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2952f06e04db> in <module>
# ----> 1 plt.imshow(prova)
#
# NameError: name 'prova' is not defined

# %%
completeimage = image_copy -mask_hsv
plt.imshow(completeimage)
